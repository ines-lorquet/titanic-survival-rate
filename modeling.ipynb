# %% [markdown]
# # Prédiction de la Survie des Passagers du Titanic

# %% [markdown]
# ## Introduction
#
# ### Ce notebook utilise PyCaret pour entraîner et comparer plusieurs modèles de classification afin de prédire la survie des passagers du Titanic.

# %% [markdown]
# ## Importation des bibliothèques

# %%
import pandas as pd
from pycaret.classification import *

# %% [markdown]
# ## Chargement des données prétraitées

# %%
file_path = 'data/titanic.csv'  
data = pd.read_csv(file_path)

# %%
# Prétraitement des données
data['Age'].fillna(data['Age'].median(), inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  28.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
data = pd.get_dummies(data, columns=['Sex', 'Embarked'], drop_first=True)
data
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  \
# 0              1         0       3  22.0      1      0   7.2500      True
# 1              2         1       1  38.0      1      0  71.2833     False
# 2              3         1       3  26.0      0      0   7.9250     False
# 3              4         1       1  35.0      1      0  53.1000     False
# 4              5         0       3  35.0      0      0   8.0500      True
# ..           ...       ...     ...   ...    ...    ...      ...       ...
# 886          887         0       2  27.0      0      0  13.0000      True
# 887          888         1       1  19.0      0      0  30.0000     False
# 888          889         0       3  28.0      1      2  23.4500     False
# 889          890         1       1  26.0      0      0  30.0000      True
# 890          891         0       3  32.0      0      0   7.7500      True
#
#      Embarked_Q  Embarked_S
# 0         False        True
# 1         False       False
# 2         False        True
# 3         False        True
# 4         False        True
# ..          ...         ...
# 886       False        True
# 887       False        True
# 888       False        True
# 889       False       False
# 890        True       False
#
# [891 rows x 10 columns]

# %% [markdown]
# ## Configuration de l'environnement PyCaret

# %%
clf1 = setup(data, target='Survived', session_id=123)
# Out:
# <style type="text/css">
# #T_687f4_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_687f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_687f4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_687f4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_687f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_687f4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_687f4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_687f4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_687f4_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_687f4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_687f4_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_687f4_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_687f4_row3_col1" class="data row3 col1" >(891, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_687f4_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_687f4_row4_col1" class="data row4 col1" >(891, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_687f4_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_687f4_row5_col1" class="data row5 col1" >(623, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_687f4_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_687f4_row6_col1" class="data row6 col1" >(268, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_687f4_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_687f4_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_687f4_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_687f4_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_687f4_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_687f4_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_687f4_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_687f4_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_687f4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T
T_b6d4f_row10_col7, #T_b6d4f_row11_col0, #T_b6d4f_row11_col1, #T_b6d4f_row11_col2, #T_b6d4f_row11_col3, #T_b6d4f_row11_col4, #T_b6d4f_row11_col5, #T_b6d4f_row11_col6, #T_b6d4f_row11_col7, #T_b6d4f_row12_col0, #T_b6d4f_row12_col1, #T_b6d4f_row12_col2, #T_b6d4f_row12_col3, #T_b6d4f_row12_col4, #T_b6d4f_row12_col5, #T_b6d4f_row12_col6, #T_b6d4f_row12_col7, #T_b6d4f_row13_col0, #T_b6d4f_row13_col1, #T_b6d4f_row13_col2, #T_b6d4f_row13_col3, #T_b6d4f_row13_col4, #T_b6d4f_row13_col5, #T_b6d4f_row13_col6, #T_b6d4f_row13_col7 {
#   text-align: left;
# }
# #T_b6d4f_row0_col1, #T_b6d4f_row0_col4, #T_b6d4f_row0_col5, #T_b6d4f_row0_col6, #T_b6d4f_row0_col7, #T_b6d4f_row2_col3, #T_b6d4f_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b6d4f_row0_col8, #T_b6d4f_row1_col8, #T_b6d4f_row2_col8, #T_b6d4f_row3_col8, #T_b6d4f_row4_col8, #T_b6d4f_row5_col8, #T_b6d4f_row7_col8, #T_b6d4f_row9_col8, #T_b6d4f_row11_col8, #T_b6d4f_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b6d4f_row6_col8, #T_b6d4f_row8_col8, #T_b6d4f_row10_col8, #T_b6d4f_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b6d4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6d4f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b6d4f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b6d4f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b6d4f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b6d4f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b6d4f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b6d4f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b6d4f_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_b6d4f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6d4f_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_b6d4f_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_b6d4f_row0_col1" class="data row0 col1" >0.8169</td>
#       <td id="T_b6d4f_row0_col2" class="data row0 col2" >0.8345</td>
#       <td id="T_b6d4f_row0_col3" class="data row0 col3" >0.7071</td>
#       <td id="T_b6d4f_row0_col4" class="data row0 col4" >0.7943</td>
#       <td id="T_b6d4f_row0_col5" class="data row0 col5" >0.7444</td>
#       <td id="T_b6d4f_row0_col6" class="data row0 col6" >0.6034</td>
#       <td id="T_b6d4f_row0_col7" class="data row0 col7" >0.6088</td>
#       <td id="T_b6d4f_row0_col8" class="data row0 col8" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_b6d4f_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_b6d4f_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_b6d4f_row1_col1" class="data row1 col1" >0.8105</td>
#       <td id="T_b6d4f_row1_col2" class="data row1 col2" >0.8419</td>
#       <td id="T_b6d4f_row1_col3" class="data row1 col3" >0.6986</td>
#       <td id="T_b6d4f_row1_col4" class="data row1 col4" >0.7917</td>
#       <td id="T_b6d4f_row1_col5" class="data row1 col5" >0.7367</td>
#       <td id="T_b6d4f_row1_col6" class="data row1 col6" >0.5903</td>
#       <td id="T_b6d4f_row1_col7" class="data row1 col7" >0.5977</td>
#       <td id="T_b6d4f_row1_col8" class="data row1 col8" >0.0510</td>
#     </tr>
#     <tr>
#       <th id="T_b6d4f_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_b6d4f_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_b6d4f_row2_col1" class="data row2 col1" >0.7993</td>
#       <td id="T_b6d4f_row2_col2" class="data row2 col2" >0.8285</td>
#       <td id="T_b6d4f_row2_col3" class="data row2 col3" >0.7408</td>
#       <td id="T_b6d4f_row2_col4" class="data row2 col4" >0.7429</td>
#       <td id="T_b6d4f_row2_col5" class="data row2 col5" >0.7371</td>
#       <td id="T_b6d4f_row2_col6" class="data row2 col6" >0.5756</td>
#       <td id="T_b6d4f_row2_col7" class="data row2 col7" >0.5801</td>
#       <td id="T_b6d4f_row2_col8" class="data row2 col8" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_b6d4f_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_b6d4f_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_b6d4f_row3_col1" class="data row3 col1" >0.7976</td>
#       <td id="T_b6d4f_row3_col2" class="data row3 col2" >0.8514</td>
#       <td id="T_b6d4f_row3_col3" class="data row3 col3" >0.7114</td>
#       <td id="T_b6d4f_row3_col4" class="data row3 col4" >0.7518</td>
#       <td id="T_b6d4f_row3_col5" class="data row3 col5" >0.7264</td>
#       <td id="T_b6d4f_row3_col6" class="data row3 col6" >0.5669</td>
#       <td id="T_b6d4f_row3_col7" class="data row3 col7" >0.5716</td>
#       <td id="T_b6d4f_row3_col8" class="data row3 col8" >0.6410</td>
#     </tr>
#     <tr>
#       <th id="T_b6d4f_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_b6d4f_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_b6d4f_row4_col1" class="data row4 col1" >0.7960</td>
#       <td id="T_b6d4f_row4_col2" class="data row4 col2" >0.8232</td>
#       <td id="T_b6d4f_row4_col3" class="data row4 col3" >0.6779</td>
#       <td id="T_b6d4f_row4_col4" class="data row4 col4" >0.7747</td>
#       <td id="T_b6d4f_row4_col5" class="data row4 col5" >0.7177</td>
#       <td id="T_b6d4f_row4_col6" class="data row4 col6" >0.5600</td>
#       <td id="T_b6d4f_row4_col7" class="data row4 col7" >0.5673</td>
#       <td id="T_b6d4f_row4_col8" class="data row4 col8" >0.1410</td>
#     </tr>
#     <tr>
#       <th id="T_b6d4f_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_b6d4f_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_b6d4f_row5_col1" class="data row5 col1" >0.7945</td>
#       <td id="T_b6d4f_row5_col2" class="data row5 col2" >0.8337</td>
#       <td id="T_b6d4f_row5_col3" class="data row5 col3" >0.6904</td>
#       <td id="T_b6d4f_row5_col4" class="data row5 col4" >0.7549</td>
#       <td id="T_b6d4f_row5_col5" class="data row5 col5" >0.7181</td>
#       <td id="T_b6d4f_row5_col6" class="data row5 col6" >0.5575</td>
#       <td id="T_b6d4f_row5_col7" class="data row5 col7" >0.5613</td>

# %% [markdown]
# ## Conclusion

# %%
print(f"Le modèle le plus performant pour prédire la survie des passagers du Titanic est {best_model.__class__.__name__}.")
# Out:
# Le modèle le plus performant pour prédire la survie des passagers du Titanic est GradientBoostingClassifier.
